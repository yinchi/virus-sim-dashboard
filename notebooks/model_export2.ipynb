# %%
import json
from virus_sim_dashboard import export

# %%
# %pwd
# Out:
# '/home/yinchi/git_projects/virus-sim-dashboard/notebooks'

# %%
data =json.load(open('./private/main_store_data.json'))

# %%
io = export.export_xlsx(data, "model_export.xlsx")
io

# %%
with open("model_export2.xlsx", "wb") as f:
    f.write(io.getvalue())
